# %%
import torch
from torchvision import datasets
from torchvision import transforms

import matplotlib.pyplot as plt
import numpy as np

# %load_ext autoreload
# %autoreload 2

# %%
import tool
from model import AE

import main

# %%
model = AE()

# %%
main.train(model, 1)
# Out:
# ...
# Bach:   0%|          | 0/1875 [00:00<?, ?it/s]
# tensor(0.2317, grad_fn=<MseLossBackward0>)
# tensor(0.2295, grad_fn=<MseLossBackward0>)
# tensor(0.2275, grad_fn=<MseLossBackward0>)
# tensor(0.2251, grad_fn=<MseLossBackward0>)
# tensor(0.2232, grad_fn=<MseLossBackward0>)
# tensor(0.2221, grad_fn=<MseLossBackward0>)
# tensor(0.2201, grad_fn=<MseLossBackward0>)
# tensor(0.2141, grad_fn=<MseLossBackward0>)
# tensor(0.2077, grad_fn=<MseLossBackward0>)
# tensor(0.1987, grad_fn=<MseLossBackward0>)
# tensor(0.1811, grad_fn=<MseLossBackward0>)
# tensor(0.1437, grad_fn=<MseLossBackward0>)
# tensor(0.0904, grad_fn=<MseLossBackward0>)
# tensor(0.0737, grad_fn=<MseLossBackward0>)
# tensor(0.0691, grad_fn=<MseLossBackward0>)
# tensor(0.0740, grad_fn=<MseLossBackward0>)
# tensor(0.0694, grad_fn=<MseLossBackward0>)
# tensor(0.0732, grad_fn=<MseLossBackward0>)
# tensor(0.0755, grad_fn=<MseLossBackward0>)
# tensor(0.0710, grad_fn=<MseLossBackward0>)
# tensor(0.0643, grad_fn=<MseLossBackward0>)
# ...

# %%
num = main.dataset[5]

pix, label = num
pix = pix.reshape(-1, 28*28)
print(pix[0][345])
generated_pix = model.encoder(pix)
print(generated_pix)
# generated_pix = generated_pix.reshape(-1, 28, 28)
# generated_num = (generated_pix.detach(), label)


# # tool.show_MNIST_digit(num)
# tool.show_MNIST_digit(generated_num)
# Out:
# tensor(0.)
# tensor([[ 0.3049,  0.2229, -0.2841, -0.3146,  0.1949, -0.0660,  0.1307, -0.1715,
#          -0.3983]], grad_fn=<AddmmBackward0>)

# %%
subset_x = []
subset_y = []
for i in range(16):
    x, y = main.dataset[i]

    subset_x.append(x)
    subset_y.append(y)

model_x_input = torch.stack(subset_x).reshape(-1, 28 * 28)
model_x_output = model(model_x_input)


tool.show_MNIST_digit_array(list(zip(subset_x, subset_y)))
tool.show_MNIST_digit_array(list(zip(model_x_output.detach().numpy(), subset_y)))
